# %% [markdown]
# <a href="https://colab.research.google.com/github/nvvishnu/CS6910-Assignments/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import the required libraries
# !pip install wandb
import pandas as pd
import numpy as np
import wandb
from keras.datasets import fashion_mnist
from matplotlib import pyplot

# %%
#Set-up the wandb project
# !wandb login 265e39ac78ea7a5514c16f131116c52112adddd6
wandb.init(project="cs6910-assignment1", entity="nvvishnu")

# %%
(trainX, trainy), (testX, testy) = fashion_mnist.load_data()
#num_classes = max(max(trainy),max(testy))
#print(num_classes) 
# To identify the number of classes in the dataset - There are 10 labels in the dataset
labelNames = ['T-shirt/top', 'Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']
# The names of label of the Fashion MNIST Dataset as per Kaggle: https://www.kaggle.com/zalando-research/fashionmnist

# %%
images=np.array()
for i in range(0,num_classes+1):
  for j in range(0,trainX.shape[0]):
    if(trainy[j]==i):
      #print(i)
      pyplot.subplot(1,1,(1,1+i))
      pyplot.title(labelNames[i])
      # plot raw pixel data
      images[i]=pyplot.imshow(trainX[i], cmap=pyplot.get_cmap('gray'),)
      # show the figure
      pyplot.show()
      break
## This creates

# %%
#Yet to implement how to log this into wandb
#wandb.log({"Question 1:", [wandb.Image(images, caption=labelNames)]})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-819374a138a9> in <module>()
# ----> 1 wandb.log({"Question 1:", [wandb.Image(images, caption=labelNames)]})
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/data_types.py in __init__(self, data_or_path, mode, caption, grouping, classes, boxes, masks)
#    1517             self._initialize_from_path(data_or_path)
#    1518         else:
# -> 1519             self._initialize_from_data(data_or_path, mode)
#    1520
#    1521         self._set_initialization_meta(grouping, caption, classes, boxes, masks)
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/data_types.py in _initialize_from_data(self, data, mode)
#    1621             if hasattr(data, "numpy"):  # TF data eager tensors
#    1622                 data = data.numpy()
# -> 1623             if data.ndim > 2:
# ...

# %%
def feed_forward(X,num_hidden_layers,num_neurons_hl,activation_function,weights,biases):
  print('dum')
